# %%
import pandas as pd
from pipeline import split_and_train_pipeline
from all_models import LinearSharpeSuperModel
from all_features import extract_features

# %%
split_and_train_pipeline(LinearSharpeSuperModel, extract_features)
# Out:
# 1. Loading raw chunk data...
# 2. Extracting 1000 sequences (Takes ~30 seconds)...
# 3. Indexing actual targets...
# 4. Slicing into Split Folds -> Train (80%) | Val (20%)...
# 5. Engaging Model.train() across 800 samples...
# Training PyTorch AD Model to directly maximize Sharpe...
# Epoch 100/500 | Loss (Negative Sharpe): -0.1538
# Epoch 200/500 | Loss (Negative Sharpe): -0.1536
# Epoch 300/500 | Loss (Negative Sharpe): -0.1534
# Epoch 400/500 | Loss (Negative Sharpe): -0.1532
# Epoch 500/500 | Loss (Negative Sharpe): -0.1530
# 6. Parsing Evaluation Vectors...
# \n=====================================
#  FINAL TRAIN SHARPE:      2.4502
#  FINAL VALIDATION SHARPE: 2.7252
# =====================================\n
# (<all_models.LinearSharpeSuperModel at 0x7f1cfbf73a10>,
#  (         seen_return  log_return  seen_volatility  max_high_ratio  \
#   session
#   29           -0.0123   -0.012376         0.006724        1.028349
# ...
