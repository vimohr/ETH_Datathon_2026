# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("data/hum_response_plan/humanitarian-response-plans.csv")
print(data.head())
# Out:
#              code internalId    startDate     endDate  \
# 0  #response+code   #meta+id  #date+start   #date+end
# 1          HHTI26       8278   2026-01-01  2026-12-31
# 2          RREG26       8215   2026-01-01  2026-12-31
# 3          FPSE26       8267   2026-01-01  2026-12-31
# 4          HMLI26       8128   2026-01-01  2026-12-31
#
#                                          planVersion  \
# 0                                     #response+name
# 1  Haiti Besoins Humanitaires et Plan de Réponse ...
# 2  Regional Migrant Response Plan for Horn of Afr...
# 3  Escalation of Hostilities in the OPT Flash App...
# 4  Mali Besoins Humanitaires et Plan de Réponse 2026
#
#                                           categories  \
# 0                                #response+type+list
# 1  Humanitarian needs and response plan | cluster...
# 2               sector | en | Regional response plan
# 3                        cluster | en | Flash appeal
# ...
